# %% [markdown]
# # **Day 12**
# ## Scope

# %% [markdown]
# ### Namespaces and Scope

# %%
enemies = 1

def increase_enemies():
    enemies = 2
    print(f"enemies inside function: {enemies}")

increase_enemies()
print(f"enemies outside function: {enemies}")
# Out:
# enemies inside function: 2
# enemies outside function: 1

# %% [markdown]
# ### Local vs. Global Scope

# %%
# Local Scope
def drink_potion():
    potion_strength = 2
    print(potion_strength)

drink_potion()
# Can't access this potion_strength outside of its scope
# print(potion_strength)
# Out:
# 2

# %%
# Global Scope
player_health = 10

def game():
    def drink_potion():
        potion_strength = 2
        print(player_health)

    drink_potion()

print(player_health)
# Out:
# 10

# %% [markdown]
# #### Does Python Have Block Scope?
# - NO (*if* blocks, *while* or *for* loops or anything that has the indentations and the colon does not create a scope)

# %%
game_level = 3
enemies = ["Skeleton", "Zombie", "Alien"]

if game_level < 5:
    new_enemy = enemies[0]

print(new_enemy)
# Out:
# Skeleton

# %%
def create_enemy():
    new_enemy = ""
    if game_level < 5:
        new_enemy = enemies[0]

    print(new_enemy)

create_enemy()
# Out:
# Skeleton

# %% [markdown]
# #### How to Modify a Global Variable

# %%
# Modifying Global Scope 1

enemies = 1

def increase_enemies():
    global enemies
    enemies += 1
    print(f"enemies inside function: {enemies}")


increase_enemies()
print(f"enemies outside function: {enemies}")
# Out:
# enemies inside function: 2
# enemies outside function: 2

# %%
# Modifying Global Scope 2 (avoid using global)

enemies = 1

# def increase_enemies():
#     global enemies
#     enemies += 1
#     print(f"enemies inside function: {enemies}")


def increase_enemies(enemy):
    print(f"enemies inside function: {enemy}")
    return enemy + 1


enemies = increase_enemies(enemies)
print(f"enemies outside function: {enemies}")
# Out:
# enemies inside function: 1
# enemies outside function: 2

# %% [markdown]
# #### Constants and Global Scope

# %%
EASY_LEVEL_TURNS = 10
HARD_LEVEL_TURNS = 5
PI = 3.14159
GOOGLE_URL = "https://google.com"
